# %%
from unet_wrapper import unet_wrapper

# %%
U = unet_wrapper("/Users/jiehyun/kaggle/output/")

# %%
kaggle_data = U.load_npy()

# %%
U.train()
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# 2022-12-05 22:09:05.802536: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 1/1 [==============================] - ETA: 0s - loss: 0.9070 - iou: 0.0328 - iou_thresholded: 0.0301 - dice_coef: 0.0635 - accuracy: 0.4917 - sparse_categorical_accuracy: 0.9580
# Epoch 1: val_loss improved from inf to 0.70692, saving model to segm_model_v3.h5
# 1/1 [==============================] - 44s 44s/step - loss: 0.9070 - iou: 0.0328 - iou_thresholded: 0.0301 - dice_coef: 0.0635 - accuracy: 0.4917 - sparse_categorical_accuracy: 0.9580 - val_loss: 0.7069 - val_iou: 0.0943 - val_iou_thresholded: 0.0913 - val_dice_coef: 0.1724 - val_accuracy: 0.6289 - val_sparse_categorical_accuracy: 0.8858
# (<keras.engine.functional.Functional at 0x385a7abc0>,
# ...

# %%
U.predict()
# Out:
# 1/1 [==============================] - ETA: 0s - loss: 0.7777 - iou: 0.1422 - iou_thresholded: 0.1643 - dice_coef: 0.2490 - accuracy: 0.5172 - sparse_categorical_accuracy: 0.8125
# Epoch 1: val_loss improved from inf to 0.62235, saving model to segm_model_v3.h5
# ...
# 2/2 [==============================] - 33s 11s/step
# array([[[[ True],
#          [ True],
#          [ True],
#          ...,
#          [ True],
#          [ True],
#          [ True]],
#
#         [[ True],
#          [ True],
#          [ True],
#          ...,
#          [ True],
#          [ True],
#          [ True]],
#
#         [[ True],
#          [ True],
#          [ True],
#          ...,
#          [ True],
#          [ True],
#          [ True]],
#
#         ...,
#
#         [[ True],
#          [ True],
#          [ True],
#          ...,
#          [ True],
#          [ True],
#          [ True]],
#
#         [[ True],
#          [ True],
#          [ True],
#          ...,
#          [ True],
# ...

# %%
U.plot_resuts()
# Out:
# 1/1 [==============================] - ETA: 0s - loss: 0.9373 - iou: 0.1281 - iou_thresholded: 0.1177 - dice_coef: 0.2272 - accuracy: 0.4864 - sparse_categorical_accuracy: 0.8209
# Epoch 1: val_loss improved from inf to 1.14692, saving model to segm_model_v3.h5
# ...
# 1/1 [==============================] - ETA: 0s - loss: 0.8497 - iou: 0.0786 - iou_thresholded: 0.0841 - dice_coef: 0.1458 - accuracy: 0.5224 - sparse_categorical_accuracy: 0.9131
# Epoch 1: val_loss improved from inf to 0.61597, saving model to segm_model_v3.h5
# 1/1 [==============================] - 37s 37s/step - loss: 0.8497 - iou: 0.0786 - iou_thresholded: 0.0841 - dice_coef: 0.1458 - accuracy: 0.5224 - sparse_categorical_accuracy: 0.9131 - val_loss: 0.6160 - val_iou: 0.0910 - val_iou_thresholded: 0.0802 - val_dice_coef: 0.1669 - val_accuracy: 0.6723 - val_sparse_categorical_accuracy: 0.8875
