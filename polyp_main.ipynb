# %%
from unet_wrapper import unet_wrapper

# %%
N = unet_wrapper("/Users/jiehyun/kaggle/input/CVC-ClinicDB/Original/", "/Users/jiehyun/kaggle/input/CVC-ClinicDB/Ground_Truth/")

# %%
N.convert_to_npy()

# %%
E = unet_wrapper("/Users/jiehyun/Jenna/UMassBoston/2022_Fall/CS696/01/output/test_img", 
"/Users/jiehyun/Jenna/UMassBoston/2022_Fall/CS696/01/output/test_mask")

# %%
x, y = E.load_npy()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
model, x_val, y_val = E.train(x, y)
# Out:
# Epoch 1/50
# 2023-01-03 14:01:21.128609: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 100/100 [==============================] - ETA: 0s - loss: 0.5780 - iou: 0.1083 - iou_thresholded: 0.2005 - dice_coef: 0.1909 - accuracy: 0.7521 - sparse_categorical_accuracy: 0.9006
# Epoch 1: val_loss improved from inf to 5.97346, saving model to segm_model_v3.h5
# 100/100 [==============================] - 314s 3s/step - loss: 0.5780 - iou: 0.1083 - iou_thresholded: 0.2005 - dice_coef: 0.1909 - accuracy: 0.7521 - sparse_categorical_accuracy: 0.9006 - val_loss: 5.9735 - val_iou: 2.9282e-05 - val_iou_thresholded: 3.1470e-06 - val_dice_coef: 5.5448e-05 - val_accuracy: 0.9005 - val_sparse_categorical_accuracy: 0.9018
# Epoch 2/50
# 100/100 [==============================] - ETA: 0s - loss: 0.3714 - iou: 0.1257 - iou_thresholded: 0.2027 - dice_coef: 0.2185 - accuracy: 0.8798 - sparse_categorical_accuracy: 0.8959
# ...

# %%
a_binary = E.predict(model, x_val)
# Out:
# 3/3 [==============================] - 34s 11s/step

# %%
plot = E.plot_resuts(a_binary, x_val, y_val)
